# %% [markdown]
# ## Projet1

# %% [markdown]
# ## Introduction
# Ce carnet présente plusieurs concepts fondamentaux de la science des données, incluant les langages utilisés, les bibliothèques les plus courantes, ainsi que des outils et exemples d'expressions arithmétiques. Chaque section illustre un aspect différent de l'écosystème de la data science.

# %% [markdown]
# ## Langages utilisés en Science des Données
# Voici quelques langages couramment utilisés dans le domaine de la science des données :
#
# - **Python**
# - **R**
# - **SQL**
# - **Julia**
# - **Scala**

# %% [markdown]
# ## Bibliothèques de Science des Données
# Quelques bibliothèques populaires utilisées par les data scientists :
#
# - **NumPy** – Manipulation de tableaux et calcul scientifique
# - **Pandas** – Analyse et manipulation de données
# - **Matplotlib** – Visualisation de données
# - **Scikit-learn** – Apprentissage automatique
# - **TensorFlow** ou **PyTorch** – Deep Learning

# %% [markdown]
# ## Outils de la Science des Données
#
# | Outil                | Description                                |
# |----------------------|--------------------------------------------|
# | Jupyter Notebook     | Environnement interactif pour coder        |
# | RStudio              | IDE pour R                                 |
# | VS Code              | Éditeur polyvalent pour le développement   |
# | GitHub               | Plateforme de gestion de versions          |
# | Tableau              | Outil de visualisation des données         |

# %% [markdown]
# ## Exemples d'Expressions Arithmétiques
# Voici quelques exemples d'opérations arithmétiques simples :
#
# - Addition : `3 + 5 = 8`
# - Soustraction : `10 - 4 = 6`
# - Multiplication : `6 * 7 = 42`
# - Division : `20 / 5 = 4`
# - Puissance : `2 ** 3 = 8`

# %%
# Multiplication
multiplication = 7 * 4
print("Résultat de la multiplication :", multiplication)

# Addition
addition = 10 + 5
print("Résultat de l'addition :", addition)
# Out:
# Résultat de la multiplication : 28
# Résultat de l'addition : 15

# %%
minutes = 120
heures = minutes / 60
print(minutes, "minutes =", heures, "heures")
# Out:
# 120 minutes = 2.0 heures

# %% [markdown]
# ## Objectifs du Carnet
#
# Les objectifs de ce carnet sont :
#
# - Comprendre les éléments fondamentaux de la science des données.
# - Pratiquer l'utilisation des cellules Markdown et des cellules de code.
# - Appliquer des opérations simples en Python.
# - Manipuler et organiser un carnet JupyterLite.
# - Préparer un document propre à soumettre pour évaluation.

# %% [markdown]
# ## Auteur
# Ce carnet a été rédigé par : **Maha Ibrahimi**
